# %%
# !unzip DrillcoreML2022-main.zip
# Out:
# Archive:  DrillcoreML2022-main.zip
#  extracting: 15EIS.csv
#  extracting: dd0001.csv
#  extracting: dd0002.csv
#  extracting: dd0003B.csv
#  extracting: dd0004.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df15EIS = pd.read_csv('15EIS.csv')

# %%
#ax.tick_params(axis='y', labelsize=32)
left_col_value = df15EIS['Au_ppm'].min()
right_col_value = df15EIS['Au_ppm'].max()+df15EIS['Au_ppm'].max()*0.20

#assign the column to a variable for easier reading
curve = df15EIS['Au_ppm']
#calculate the span of values
span = abs(left_col_value - right_col_value)
# print(span)
#assign a color map
cmap = plt.get_cmap('nipy_spectral')

#create array of values to divide up the area under curve
color_index = np.arange(left_col_value, right_col_value, span / 100)
#setup the plot
#df15EIS.plot(x='Res_Deep', y='Depth_m', c='black', lw=0.5, legend=False, figsize=(3,10))
df15EIS.plot(y='Au_ppm', x='Depth_m', c='black', lw=0.5, legend=False, figsize=(10,1.2),fontsize=15)
plt.xlim(1350, 1500)
plt.xlabel('Depth(m)', fontsize=24)
plt.ylabel('Au_ppm',rotation=90,fontsize=20)
plt.xticks(fontsize=20)
#plt.yticks(np.arange(0, 2450, 250))
plt.grid(False)
plt.ylim( df15EIS['Au_ppm'].min(),  df15EIS['Au_ppm'].max()+ df15EIS['Au_ppm'].max()*0.20)
#plt.title('Plot With a Variable Fill to Y-Axis')

#loop through each value in the color_index
for index in sorted(color_index):
    # print(index)
    index_value = (index - left_col_value)/span
    # print(index_value)
    color = cmap(index_value) #obtain colour for color index value
    plt.fill_between(df15EIS['Depth_m'], curve, 0, where = curve >= index,  color = color)
    
plt.show()

# %%
#ax.tick_params(axis='y', labelsize=32)
left_col_value = df15EIS['Al_ppm'].min()
right_col_value = df15EIS['Al_ppm'].max()+df15EIS['Al_ppm'].max()*0.20

#assign the column to a variable for easier reading
curve = df15EIS['Al_ppm']
#calculate the span of values
span = abs(left_col_value - right_col_value)
# print(span)
#assign a color map
cmap = plt.get_cmap('nipy_spectral')

#create array of values to divide up the area under curve
color_index = np.arange(left_col_value, right_col_value, span / 100)
#setup the plot
#df15EIS.plot(x='Res_Deep', y='Depth_m', c='black', lw=0.5, legend=False, figsize=(3,10))
df15EIS.plot(y='Al_ppm', x='Depth_m', c='black', lw=0.5, legend=False, figsize=(10,1.2),fontsize=15)
plt.xlim(1350, 1500)
plt.xlabel('Depth(m)', fontsize=24)
plt.ylabel('Al_ppm',rotation=90,fontsize=20)
plt.xticks(fontsize=20)
#plt.yticks(np.arange(0, 2450, 250))
plt.grid(False)
plt.ylim( df15EIS['Al_ppm'].min(),  df15EIS['Al_ppm'].max()+ df15EIS['Al_ppm'].max()*0.20)
#plt.title('Plot With a Variable Fill to Y-Axis')

#loop through each value in the color_index
for index in sorted(color_index):
    # print(index)
    index_value = (index - left_col_value)/span
    # print(index_value)
    color = cmap(index_value) #obtain colour for color index value
    plt.fill_between(df15EIS['Depth_m'], curve, 0, where = curve >= index,  color = color)
    
plt.show()

# %%
#ax.tick_params(axis='y', labelsize=32)
left_col_value = df15EIS['Cu_ppm'].min()
right_col_value = df15EIS['Cu_ppm'].max()+df15EIS['Cu_ppm'].max()*0.20

#assign the column to a variable for easier reading
curve = df15EIS['Cu_ppm']
#calculate the span of values
span = abs(left_col_value - right_col_value)
# print(span)
#assign a color map
cmap = plt.get_cmap('nipy_spectral')

#create array of values to divide up the area under curve
color_index = np.arange(left_col_value, right_col_value, span / 100)
#setup the plot
#df15EIS.plot(x='Res_Deep', y='Depth_m', c='black', lw=0.5, legend=False, figsize=(3,10))
df15EIS.plot(y='Cu_ppm', x='Depth_m', c='black', lw=0.5, legend=False, figsize=(10,1.2),fontsize=15)
plt.xlim(1350, 1500)
plt.xlabel('Depth(m)', fontsize=24)
plt.ylabel('Cu_ppm',rotation=90,fontsize=20)
plt.xticks(fontsize=20)
#plt.yticks(np.arange(0, 2450, 250))
plt.grid(False)
plt.ylim( df15EIS['Cu_ppm'].min(),  df15EIS['Cu_ppm'].max()+ df15EIS['Cu_ppm'].max()*0.005)
#plt.title('Plot With a Variable Fill to Y-Axis')

#loop through each value in the color_index
for index in sorted(color_index):
    # print(index)
    index_value = (index - left_col_value)/span
    # print(index_value)
    color = cmap(index_value) #obtain colour for color index value
    plt.fill_between(df15EIS['Depth_m'], curve, 0, where = curve >= index,  color = color)
    
plt.show()

# %%
#ax.tick_params(axis='y', labelsize=32)
left_col_value = df15EIS['Ag_ppm'].min()
right_col_value = df15EIS['Ag_ppm'].max()+df15EIS['Ag_ppm'].max()*0.20

#assign the column to a variable for easier reading
curve = df15EIS['Ag_ppm']
#calculate the span of values
span = abs(left_col_value - right_col_value)
# print(span)
#assign a color map
cmap = plt.get_cmap('nipy_spectral')

#create array of values to divide up the area under curve
color_index = np.arange(left_col_value, right_col_value, span / 100)
#setup the plot
#df15EIS.plot(x='Res_Deep', y='Depth_m', c='black', lw=0.5, legend=False, figsize=(3,10))
df15EIS.plot(y='Ag_ppm', x='Depth_m', c='black', lw=0.5, legend=False, figsize=(10,1.2),fontsize=15)
plt.xlim(1350, 1500)
plt.xlabel('Depth(m)', fontsize=24)
plt.ylabel('Ag_ppm',rotation=90,fontsize=20)
plt.xticks(fontsize=20)
#plt.yticks(np.arange(0, 2450, 250))
plt.grid(False)
plt.ylim( df15EIS['Ag_ppm'].min(),  df15EIS['Ag_ppm'].max()+ df15EIS['Ag_ppm'].max()*0.20)
#plt.title('Plot With a Variable Fill to Y-Axis')

#loop through each value in the color_index
for index in sorted(color_index):
    # print(index)
    index_value = (index - left_col_value)/span
    # print(index_value)
    color = cmap(index_value) #obtain colour for color index value
    plt.fill_between(df15EIS['Depth_m'], curve, 0, where = curve >= index,  color = color)
    
plt.show()
